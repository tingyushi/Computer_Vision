# %% [markdown]
# # Image Classification using AlexNet
# ![](images/AlexNet.png)
#
# ## Activation Function
# ReLU

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
import tensorflow.keras.datasets.mnist as mnist
import tensorflow.keras as keras
from progressbar import progressbar
import os
import random
# Out:
# 2023-07-28 02:37:32.501666: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load data

# %%
class Dog():
    def __init__(self):
        self.image_values = None
        self.label = None
        self.id = None

def data_loader():
    '''
    Return a list containing Dog objects
    '''
    
    # defind some constant
    IMAGE_PATH = 'datasets/Stanford_Dogs_Dataset/Images'

    # construct id to label dictionary and vice versa
    id2label = {}
    label2id = {}
    id_counter = 0
    for images_folder in os.listdir(IMAGE_PATH):
        if not images_folder.startswith('.'):
            label = images_folder
            id2label[id_counter] = label
            label2id[label] = id_counter
            id_counter += 1
    
    dogs = []
    for dog_type in progressbar( os.listdir(IMAGE_PATH) ):
        if not dog_type.startswith('.'):
            label = dog_type
            id = label2id[label]
            for dog_image in os.listdir(os.path.join(IMAGE_PATH, dog_type)):
                if not dog_image.startswith('.'):
                    temp_dog = Dog()
                    temp_dog.id = id
                    temp_dog.label = label
                    temp_dog.image_values = plt.imread(os.path.join(IMAGE_PATH,
                                                                    dog_type,
                                                                    dog_image))
                    dogs.append(temp_dog)
    
    random.shuffle(dogs)

    return id2label, label2id, dogs

id2label, label2id, dogs = data_loader()

num_classes = len(id2label)
print(f"{num_classes} different types of dogs")
print(f"Total number of images: {len(dogs)}")
# Out:
# 100% (120 of 120) |######################| Elapsed Time: 0:00:46 Time:  0:00:46
# 120 different types of dogs
# Total number of images: 20580

# %%
def generate_data_array(IMAGE_HEIGHT, IMAGE_WIDTH, dogs):
    
    #seperate into tree sets
    trainset = dogs[0 : int(0.6*len(dogs))]
    cvset = dogs[int(0.6*len(dogs)) : int(0.8 * len(dogs))]
    testset = dogs[int(0.8 * len(dogs)) : len(dogs)]
    
    
    # prepare x_train and y_train
    x_train = np.ones((len(trainset) , IMAGE_HEIGHT, IMAGE_WIDTH, 3)) 
    y_train = np.ones( len(trainset) )
    for idx , dog in progressbar( enumerate(trainset) ):
        img = dog.image_values
        img = tf.image.resize(img, (IMAGE_HEIGHT, IMAGE_WIDTH))
        x_train[idx] = img[:,:,0:3]
        y_train[idx] = dog.id

    # prepare x_cv and y_cv
    x_cv = np.ones((len(cvset) , IMAGE_HEIGHT, IMAGE_WIDTH, 3))  
    y_cv = np.ones( len(cvset) )
    for idx , dog in progressbar( enumerate(cvset) ):
        img = dog.image_values
        img = tf.image.resize(img, (IMAGE_HEIGHT, IMAGE_WIDTH))
        x_cv[idx] = img[:,:,0:3]
        y_cv[idx] = dog.id

    # prepare x_test and y_test
    x_test = np.ones((len(testset) , IMAGE_HEIGHT, IMAGE_WIDTH, 3)) 
    y_test = np.ones( len(testset) )
    for idx , dog in progressbar( enumerate(testset) ):
        img = dog.image_values
        img = tf.image.resize(img, (IMAGE_HEIGHT, IMAGE_WIDTH))
        x_test[idx] = img[:,:,0:3]
        y_test[idx] = dog.id
    
    y_train = np.uint8(y_train)
    y_cv = np.uint8(y_cv)
    y_test = np.uint8(y_test)
    
    return x_train, y_train, x_cv, y_cv, x_test, y_test


x_train,y_train,x_cv,y_cv,x_test,y_test=generate_data_array(227, 227, dogs)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_cv shape: {x_cv.shape}")
print(f"y_cv shape: {y_cv.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# / |#                                                  | 0 Elapsed Time: 0:00:002023-07-27 12:44:33.452014: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-27 12:44:33.452186: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# | |                           #                   | 12347 Elapsed Time: 0:00:40
# | |         #                                      | 4115 Elapsed Time: 0:00:20
# | |                                          #     | 4115 Elapsed Time: 0:00:23
# x_train shape: (12348, 227, 227, 3)
# y_train shape: (12348,)
# x_cv shape: (4116, 227, 227, 3)
# y_cv shape: (4116,)
# x_test shape: (4116, 227, 227, 3)
# y_test shape: (4116,)

# %%
def display_dog_image(rgb, label):
    plt.imshow(np.uint8(rgb))
    plt.title(label)

display_dog_image(x_train[0], id2label[y_train[0]])

# %%
# normalize the data
x_train /= 255
x_cv /= 255
x_test /= 255

# %% [markdown]
# ## Build AlexNet Model

# %%
alexnet = tf.keras.Sequential([
    tf.keras.Input(shape=(227, 227, 3)),
    
    ########################################
    
    tfl.Conv2D(filters = 96,
               kernel_size = (11, 11),
               strides = (4, 4),
               padding ='valid',
               activation ='relu'),
    
    tfl.MaxPooling2D(pool_size = (3, 3),
                     strides = (2, 2)),
    
    ######################################
    
    ######################################
    
    tfl.Conv2D(filters = 256,
               kernel_size = (5, 5),
               strides = (1, 1),
               padding ='same',
               activation ='relu'),
    
    tfl.MaxPooling2D(pool_size = (3, 3),
                     strides = (2, 2)),
    
    ######################################
    
    ######################################
    tfl.Conv2D(filters = 384,
               kernel_size = (3, 3),
               strides = (1, 1),
               padding ='same',
               activation ='relu'),
    
    tfl.Conv2D(filters = 384,
               kernel_size = (3, 3),
               strides = (1, 1),
               padding ='same',
               activation ='relu'),
    
    tfl.Conv2D(filters = 256,
               kernel_size = (3, 3),
               strides = (1, 1),
               padding ='same',
               activation ='relu'),
    
    tfl.MaxPooling2D(pool_size = (3, 3),
                     strides = (2, 2)),
   
    #######################################
    
    #######################################
    tfl.Flatten(),
    
    tfl.Dense(units = 4096, activation ='relu'),
    
    tfl.Dense(units = 4096, activation ='relu'),

    tfl.Dense(units = 120, activation ='softmax')
        ])

# %%
alexnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 55, 55, 96)        34944
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 120)               491640
#
# =================================================================
# Total params: 58,772,984
# Trainable params: 58,772,984
# Non-trainable params: 0
# _________________________________________________________________

# %%
alexnet.compile(loss = 'sparse_categorical_crossentropy',
                optimizer = 'adam',
                metrics = ['accuracy'])

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              mode='min',  verbose=1, 
                                              patience=5)

y_train = np.uint8(y_train)
y_cv = np.uint8(y_cv)

alexnet.fit(x_train, 
            y_train,
            epochs = 10,
            validation_data = (x_cv, y_cv),
            callbacks=[early_stop])
# Out:
# Epoch 1/10
# 2023-07-27 12:18:27.838938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-07-27 12:18:27.927879: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# 386/386 [==============================] - ETA: 0s - loss: 4.8499 - accuracy: 0.0114
# 2023-07-27 12:19:34.550064: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 386/386 [==============================] - 73s 180ms/step - loss: 4.8499 - accuracy: 0.0114 - val_loss: 4.8417 - val_accuracy: 0.0102
# Epoch 2/10
# 386/386 [==============================] - 46s 118ms/step - loss: 4.8340 - accuracy: 0.0091 - val_loss: 4.8270 - val_accuracy: 0.0109
# Epoch 3/10
# 386/386 [==============================] - 44s 115ms/step - loss: 4.8332 - accuracy: 0.0100 - val_loss: 4.8356 - val_accuracy: 0.0090
# Epoch 4/10
# 386/386 [==============================] - 44s 113ms/step - loss: 4.8357 - accuracy: 0.0086 - val_loss: 4.8303 - val_accuracy: 0.0078
# Epoch 5/10
# 386/386 [==============================] - 44s 113ms/step - loss: 4.8369 - accuracy: 0.0085 - val_loss: 4.8425 - val_accuracy: 0.0073
# Epoch 6/10
# 386/386 [==============================] - 43s 113ms/step - loss: 4.8349 - accuracy: 0.0091 - val_loss: 4.8312 - val_accuracy: 0.0112
# Epoch 7/10
# 386/386 [==============================] - 44s 113ms/step - loss: 4.8386 - accuracy: 0.0103 - val_loss: 4.8290 - val_accuracy: 0.0085
# Epoch 7: early stopping

# %%
model_loss = pd.DataFrame(alexnet.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
alexnet.evaluate(x_test, y_test)
# Out:
# 129/129 [==============================] - 4s 30ms/step - loss: 4.8256 - accuracy: 0.0092
# [4.825605392456055, 0.009232264012098312]

# %% [markdown]
# ## AlexNet cannot handle this data set
#
# ## Solution: use transfer learning [(reference)](https://pub.towardsai.net/deep-learning-for-dog-breed-classification-77ef182a2509)

# %%
x_train,y_train,x_cv,y_cv,x_test,y_test=generate_data_array(224,224,dogs)
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_cv shape: {x_cv.shape}")
print(f"y_cv shape: {y_cv.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# | |                                            #  | 12347 Elapsed Time: 0:01:10
# | |                                              # | 4115 Elapsed Time: 0:00:23
# | |                                      #         | 4115 Elapsed Time: 0:00:23
# x_train shape: (12348, 224, 224, 3)
# y_train shape: (12348,)
# x_cv shape: (4116, 224, 224, 3)
# y_cv shape: (4116,)
# x_test shape: (4116, 224, 224, 3)
# y_test shape: (4116,)

# %%
x_train /= 225
x_cv /= 225
x_test /= 225

# %%
from tensorflow.keras.applications import inception_v3

inception_bottleneck = inception_v3.InceptionV3(weights='imagenet', 
                                                include_top=False, 
                                                pooling='avg')

temp_train = inception_bottleneck.predict(x_train, 
                                          batch_size=32, 
                                          verbose=1)

temp_cv = inception_bottleneck.predict(x_cv, 
                                       batch_size=32, 
                                       verbose=1)


temp_test = inception_bottleneck.predict(x_test, 
                                         batch_size=32, 
                                         verbose=1)
# Out:
# 2023-07-27 12:51:46.036554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 386/386 [==============================] - 32s 78ms/step
# 129/129 [==============================] - 11s 83ms/step
# 129/129 [==============================] - 12s 95ms/step

# %%
model = tf.keras.Sequential([
    tfl.Flatten(),
    
    tfl.Dense(1024, activation='relu'),
    
    tfl.Dense(1024, activation='relu'),
    
    tfl.Dense(120, activation='softmax')
        ])

model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.fit(temp_train, 
          y_train, 
          epochs=50, 
          batch_size=32,
          validation_data=(temp_cv, y_cv))
# Out:
# Epoch 1/50
# 2023-07-27 12:53:38.967021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-07-27 12:53:39.011536: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# 386/386 [==============================] - ETA: 0s - loss: 9.6000 - accuracy: 0.1009
# 2023-07-27 12:53:43.779015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 386/386 [==============================] - 6s 14ms/step - loss: 9.6000 - accuracy: 0.1009 - val_loss: 16.4836 - val_accuracy: 0.2583
# Epoch 2/50
# 386/386 [==============================] - 5s 13ms/step - loss: 17.8338 - accuracy: 0.1540 - val_loss: 35.1177 - val_accuracy: 0.4052
# Epoch 3/50
# 386/386 [==============================] - 5s 12ms/step - loss: 26.1388 - accuracy: 0.2082 - val_loss: 42.3050 - val_accuracy: 0.5352
# Epoch 4/50
# 386/386 [==============================] - 5s 13ms/step - loss: 30.6382 - accuracy: 0.2450 - val_loss: 49.1267 - val_accuracy: 0.5955
# Epoch 5/50
# 386/386 [==============================] - 5s 13ms/step - loss: 33.5720 - accuracy: 0.2677 - val_loss: 53.0690 - val_accuracy: 0.6173
# Epoch 6/50
# 386/386 [==============================] - 5s 13ms/step - loss: 36.7091 - accuracy: 0.2822 - val_loss: 49.3387 - val_accuracy: 0.6856
# Epoch 7/50
# 386/386 [==============================] - 5s 13ms/step - loss: 33.0198 - accuracy: 0.3078 - val_loss: 54.5235 - val_accuracy: 0.6664
# Epoch 8/50
# 386/386 [==============================] - 5s 12ms/step - loss: 34.9857 - accuracy: 0.3154 - val_loss: 55.4725 - val_accuracy: 0.6944
# Epoch 9/50
# 386/386 [==============================] - 5s 13ms/step - loss: 36.9891 - accuracy: 0.3175 - val_loss: 64.2898 - val_accuracy: 0.7007
# Epoch 10/50
# 386/386 [==============================] - 5s 13ms/step - loss: 37.5243 - accuracy: 0.3213 - val_loss: 64.0076 - val_accuracy: 0.7055
# Epoch 11/50
# 386/386 [==============================] - 5s 12ms/step - loss: 32.6751 - accuracy: 0.3373 - val_loss: 68.9757 - val_accuracy: 0.7133
# Epoch 12/50
# 386/386 [==============================] - 5s 12ms/step - loss: 32.5603 - accuracy: 0.3401 - val_loss: 76.8097 - val_accuracy: 0.6990
# Epoch 13/50
# 386/386 [==============================] - 5s 13ms/step - loss: 35.6871 - accuracy: 0.3442 - val_loss: 70.5456 - val_accuracy: 0.7196
# Epoch 14/50
# 386/386 [==============================] - 5s 12ms/step - loss: 35.4378 - accuracy: 0.3451 - val_loss: 77.4644 - val_accuracy: 0.7119
# Epoch 15/50
# 386/386 [==============================] - 5s 12ms/step - loss: 34.5260 - accuracy: 0.3526 - val_loss: 85.0101 - val_accuracy: 0.7177
# Epoch 16/50
# 386/386 [==============================] - 5s 12ms/step - loss: 39.3801 - accuracy: 0.3480 - val_loss: 86.3753 - val_accuracy: 0.7281
# Epoch 17/50
# 386/386 [==============================] - 5s 13ms/step - loss: 34.0229 - accuracy: 0.3591 - val_loss: 88.6821 - val_accuracy: 0.7286
# Epoch 18/50
# 386/386 [==============================] - 5s 13ms/step - loss: 34.5603 - accuracy: 0.3614 - val_loss: 92.9519 - val_accuracy: 0.7194
# Epoch 19/50
# 386/386 [==============================] - 5s 13ms/step - loss: 38.4985 - accuracy: 0.3593 - val_loss: 115.3264 - val_accuracy: 0.7102
# Epoch 20/50
# 386/386 [==============================] - 5s 13ms/step - loss: 38.3030 - accuracy: 0.3649 - val_loss: 113.7280 - val_accuracy: 0.7211
# Epoch 21/50
# 386/386 [==============================] - 5s 13ms/step - loss: 38.3537 - accuracy: 0.3662 - val_loss: 126.1065 - val_accuracy: 0.7075
# Epoch 22/50
# 386/386 [==============================] - 5s 13ms/step - loss: 37.6073 - accuracy: 0.3707 - val_loss: 112.4224 - val_accuracy: 0.7286
# Epoch 23/50
# 386/386 [==============================] - 5s 12ms/step - loss: 35.8057 - accuracy: 0.3762 - val_loss: 121.0447 - val_accuracy: 0.7228
# Epoch 24/50
# 386/386 [==============================] - 5s 13ms/step - loss: 35.1939 - accuracy: 0.3797 - val_loss: 135.4198 - val_accuracy: 0.7174
# Epoch 25/50
# 386/386 [==============================] - 5s 13ms/step - loss: 41.0375 - accuracy: 0.3745 - val_loss: 147.4944 - val_accuracy: 0.7208
# Epoch 26/50
# 386/386 [==============================] - 5s 13ms/step - loss: 44.1165 - accuracy: 0.3749 - val_loss: 154.9390 - val_accuracy: 0.7165
# Epoch 27/50
# 386/386 [==============================] - 5s 13ms/step - loss: 41.1143 - accuracy: 0.3812 - val_loss: 159.1604 - val_accuracy: 0.7157
# Epoch 28/50
# 386/386 [==============================] - 5s 13ms/step - loss: 38.7981 - accuracy: 0.3844 - val_loss: 166.9126 - val_accuracy: 0.7230
# Epoch 29/50
# 386/386 [==============================] - 5s 13ms/step - loss: 41.4999 - accuracy: 0.3847 - val_loss: 160.1905 - val_accuracy: 0.7211
# Epoch 30/50
# 386/386 [==============================] - 5s 13ms/step - loss: 43.5828 - accuracy: 0.3832 - val_loss: 165.8190 - val_accuracy: 0.7371
# Epoch 31/50
# 386/386 [==============================] - 5s 13ms/step - loss: 36.7621 - accuracy: 0.3925 - val_loss: 166.6657 - val_accuracy: 0.7228
# Epoch 32/50
# 386/386 [==============================] - 5s 13ms/step - loss: 43.1716 - accuracy: 0.3909 - val_loss: 185.9199 - val_accuracy: 0.7267
# Epoch 33/50
# 386/386 [==============================] - 5s 13ms/step - loss: 43.7607 - accuracy: 0.3882 - val_loss: 190.5222 - val_accuracy: 0.7216
# Epoch 34/50
# 386/386 [==============================] - 5s 13ms/step - loss: 49.9654 - accuracy: 0.3870 - val_loss: 183.6711 - val_accuracy: 0.7366
# Epoch 35/50
# 386/386 [==============================] - 5s 13ms/step - loss: 41.9016 - accuracy: 0.3957 - val_loss: 189.4391 - val_accuracy: 0.7383
# Epoch 36/50
# 386/386 [==============================] - 5s 13ms/step - loss: 43.2958 - accuracy: 0.3968 - val_loss: 209.1147 - val_accuracy: 0.7238
# Epoch 37/50
# 386/386 [==============================] - 5s 13ms/step - loss: 43.1676 - accuracy: 0.3961 - val_loss: 200.6387 - val_accuracy: 0.7449
# Epoch 38/50
# 386/386 [==============================] - 5s 13ms/step - loss: 49.8698 - accuracy: 0.3918 - val_loss: 221.9205 - val_accuracy: 0.7398
# Epoch 39/50
# 386/386 [==============================] - 5s 13ms/step - loss: 45.5878 - accuracy: 0.3997 - val_loss: 242.6803 - val_accuracy: 0.7274
# Epoch 40/50
# 386/386 [==============================] - 5s 13ms/step - loss: 47.3348 - accuracy: 0.3985 - val_loss: 238.3189 - val_accuracy: 0.7242
# Epoch 41/50
# 386/386 [==============================] - 5s 13ms/step - loss: 46.6763 - accuracy: 0.4006 - val_loss: 237.1235 - val_accuracy: 0.7354
# Epoch 42/50
# 386/386 [==============================] - 5s 13ms/step - loss: 52.2188 - accuracy: 0.4000 - val_loss: 246.0672 - val_accuracy: 0.7332
# Epoch 43/50
# 386/386 [==============================] - 5s 13ms/step - loss: 45.4498 - accuracy: 0.4041 - val_loss: 252.1270 - val_accuracy: 0.7357
# Epoch 44/50
# 386/386 [==============================] - 5s 13ms/step - loss: 49.4375 - accuracy: 0.4030 - val_loss: 261.7249 - val_accuracy: 0.7267
# Epoch 45/50
# 386/386 [==============================] - 5s 13ms/step - loss: 49.0380 - accuracy: 0.4066 - val_loss: 247.8091 - val_accuracy: 0.7393
# Epoch 46/50
# 386/386 [==============================] - 5s 13ms/step - loss: 55.2802 - accuracy: 0.4005 - val_loss: 260.2946 - val_accuracy: 0.7393
# Epoch 47/50
# 386/386 [==============================] - 5s 13ms/step - loss: 44.8317 - accuracy: 0.4069 - val_loss: 255.8995 - val_accuracy: 0.7398
# Epoch 48/50
# 386/386 [==============================] - 5s 13ms/step - loss: 59.6551 - accuracy: 0.4016 - val_loss: 300.3294 - val_accuracy: 0.7303
# Epoch 49/50
# 386/386 [==============================] - 5s 13ms/step - loss: 60.5771 - accuracy: 0.4004 - val_loss: 291.1219 - val_accuracy: 0.7306
# Epoch 50/50
# 386/386 [==============================] - 5s 13ms/step - loss: 50.1436 - accuracy: 0.4069 - val_loss: 290.8156 - val_accuracy: 0.7335

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
model.evaluate(temp_test, y_test)
# Out:
# 129/129 [==============================] - 1s 7ms/step - loss: 288.1238 - accuracy: 0.7332
# [288.123779296875, 0.7332361340522766]
